# %% [markdown]
# ## Data preparation and modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image

# %%
X_train = pd.read_csv("data/X_train.csv")
Y_train  = pd.read_csv("data/Y_train.csv")
X_test = pd.read_csv("data/X_test.csv")

# %%
X_train.head()
# Out:
#                site_name  company_name  \
# 0       Carrières Daniel           NaN
# 1         Malet Horgues.           NaN
# 2          Carrieres Plo           NaN
# 3  Dastugue Jean et Fils           NaN
# 4  Pema Carrières Du Roc           NaN
#
#                                                 link  latitude  longitude  \
# 0  https://www.google.com/maps/place/Carri%C3%A8r...   43.0477    -0.0473
# 1  https://www.google.com/maps/place/Malet+Horgue...   43.1903     0.0916
# 2  https://www.google.com/maps/place/Carrieres+Pl...   42.9605     0.3937
# 3  https://www.google.com/maps/place/Dastugue+Jea...   43.0689     0.3865
# 4  https://www.google.com/maps/place/Pema+Carri%C...   43.6493     0.3439
#
#                                              address homepage    phone  \
# 0                      Le Village, 65100 Ger, France      NaN  #ERROR!
# 1             Chem. de Mansas, 65310 Horgues, France      NaN      NaN
# 2                       Village, 65410 Ilhet, France      NaN  #ERROR!
# 3  Rue du Bas Mour, 65250 La Barthe-de-Neste, France      NaN  #ERROR!
# 4                             32320 Riguepeu, France      NaN  #ERROR!
#
#    sales_phone  email  sales_email opening_hours site_type  \
# 0          NaN    NaN          NaN           NaN    Quarry
# 1          NaN    NaN          NaN           NaN    Quarry
# 2          NaN    NaN          NaN           NaN    Quarry
# 3          NaN    NaN          NaN           NaN    Quarry
# 4          NaN    NaN          NaN           NaN    Quarry
#
#                                      id  \
# 0  949a5a8b-8e9d-40c5-8100-2f30a3e82f7b
# 1  044d1092-4bb7-4e09-b073-113037a0a196
# 2  738e1bd8-6a64-40a9-85ff-c442965db618
# 3  1e07b5a8-b697-4971-bc39-b57d05084eea
# 4  e96a46a3-9be3-4d3d-a3ec-2563c0e13ef2
#
#                                           image_path
# 0  data/images/train/949a5a8b-8e9d-40c5-8100-2f30...
# 1  data/images/train/044d1092-4bb7-4e09-b073-1130...
# 2  data/images/train/738e1bd8-6a64-40a9-85ff-c442...
# 3  data/images/train/1e07b5a8-b697-4971-bc39-b57d...
# 4  data/images/train/e96a46a3-9be3-4d3d-a3ec-2563...

# %%
Y_train.head()
# Out:
#    output
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0

# %%
X_test.head()
# Out:
#                                            site_name company_name  \
# 0  New Enterprise Stone &amp; Lime Co., Inc. -- A...      Unknown
# 1  New Enterprise Stone &amp; Lime Co., Inc. -- R...      Unknown
# 2  New Enterprise Stone &amp; Lime Co., Inc. -- T...      Unknown
# 3  New Enterprise Stone &amp; Lime Co., Inc. -- U...      Unknown
# 4                            Penn State Stone Valley      Unknown
#
#                                                 link  latitude  longitude  \
# 0  https://www.google.com/maps/place/New+Enterpri...   40.0046   -78.4190
# 1  https://www.google.com/maps/place/New+Enterpri...   40.3455   -78.4039
# 2  https://www.google.com/maps/place/New+Enterpri...   40.6653   -78.2130
# 3  https://www.google.com/maps/place/New+Enterpri...   40.6205   -78.1673
# 4  https://www.google.com/maps/place/Penn+State+S...   40.4848   -78.0103
#
#                                              address                homepage  \
# 0   526 Ashcom Rd, Everett, PA 15537, United States                 nesl.com
# 1  8078 Woodbury Pike, Roaring Spring, PA 16673, ...                nesl.com
# 2  853 Birmingham Pike, Tyrone, PA 16686, United ...                nesl.com
# 3  3279 Johnson Hill, Tyrone, PA 16686, United St...                nesl.com
# 4         RR 2, Huntingdon, PA 16652, United States   studentaffairs.psu.edu
#
#              phone  sales_phone  email  sales_email opening_hours  \
# 0  +1 800-426-7334          NaN    NaN          NaN           NaN
# 1  +1 800-426-7334          NaN    NaN          NaN           NaN
# 2  +1 800-426-7334          NaN    NaN          NaN           NaN
# 3  +1 800-426-7334          NaN    NaN          NaN           NaN
# 4  +1 814-667-3458          NaN    NaN          NaN           NaN
#
#             site_type                                    id  \
# 0              Quarry  2c454368-0cff-4195-8290-4cfaab9082ec
# 1              Quarry  8ac10caa-24a9-475e-9dc7-4532cb818bff
# 2  Aggregate supplier  dc097ae3-d1a9-4c88-aec6-82858d70a8eb
# 3              Quarry  aff045a5-d1d1-4713-8a99-99371965bc78
# 4      Stone supplier  b5240514-6833-49e4-902a-887495ea6952
#
#                                           image_path
# 0  data/images/test/2c454368-0cff-4195-8290-4cfaa...
# 1  data/images/test/8ac10caa-24a9-475e-9dc7-4532c...
# 2  data/images/test/dc097ae3-d1a9-4c88-aec6-82858...
# 3  data/images/test/aff045a5-d1d1-4713-8a99-99371...
# 4  data/images/test/b5240514-6833-49e4-902a-88749...

# %% [markdown]
# ## site_type

# %%
X_train.site_type.unique()
# Out:
# array(['Quarry', 'Recycling center', 'Gravel pit', 'Manufacturer',
#        'Natural stone supplier', 'Granite supplier',
#        'Concrete contractor', 'Ravine', 'Mine',
#        'Building materials supplier'], dtype=object)

# %%
X_test.site_type.unique()
# Out:
# array(['Quarry', 'Aggregate supplier', 'Stone supplier',
#        'General contractor', 'Sand plant', 'Sand & gravel supplier',
#        'Crushed stone supplier', 'Gravel pit', 'Mine', 'Mining company',
#        nan, 'Ravine', 'Ready mix concrete supplier', 'Natural feature',
#        'River', 'Natural stone supplier', 'Manufacturer', 'Rock climbing',
#        'Construction company', 'Granite supplier', 'Superfund site',
#        'Countertop store', 'Lake', 'Banquet hall', 'Mountain peak',
#        'Place of worship', 'Shoe store', 'Park', 'Apartment building',
#        'Veterans center', 'Honey farm', 'ATM', 'Training centre',
#        'Pentecostal church', 'SCUBA tour agency', 'Tourist attraction',
#        'Commercial refrigeration', 'Janitorial service',
#        'Septic system service', 'Pharmacy', 'Engraver',
#        'Gymnastics center', 'Historical landmark', 'Garden center',
#        'Self-storage facility', 'Excavating contractor', 'Plumber',
#        'Recreation center', 'Hiking area', 'Pond', 'Quilt shop',
#        'University', 'Coffee shop', 'Masonry contractor', 'Ranch',
#        'Small engine repair service', 'Building materials supplier',
#        'Liquidator', 'Bus stop', 'Bus station', 'Metal fabricator',
#        'Fishing club', 'Event venue', 'Garbage collection service',
#        'Fishing pond', 'Lumber store', 'Waste management service',
#        'Single sex secondary school', 'Roofing contractor',
#        'Corporate office', 'Sports complex', "Homeowners' association",
#        'Construction equipment supplier', 'Wedding venue',
#        'Nature preserve', 'Association or organization', 'Tire shop',
#        'Mountain cabin', 'Pallet supplier', 'American restaurant',
#        'Bridge', 'United Methodist church', 'Landscaping supply store',
#        'Business center', 'Farm', 'Shopping mall',
#        'Paving materials supplier', 'Housing complex', 'Airport',
#        'Gift shop', 'Public bathroom', 'Elementary school', 'Brewery',
#        'City government office', 'Homestay', 'Tree service',
#        'Packaging supply store', 'Fertilizer supplier',
#        'Physical therapy clinic', 'Equestrian facility', 'Cemetery',
#        'Weather forecast service', 'Trucking company',
#        'Paving contractor', 'Demolition contractor', 'Steel distributor',
#        'Lawn care service', 'Painting'], dtype=object)

# %%
for dataset in [X_train,
                X_test] :
    display(f'Quarry proportion within the dataset : {len(dataset.loc[dataset.site_type=="Quarry"]) / len(dataset)}')
# Out:
# 'Quarry proportion within the dataset : 0.9692011549566891'
# 'Quarry proportion within the dataset : 0.3485714285714286'

# %% [markdown]
# A small part of the train set is not labellised as quarry, but the labels are close it may enter in a large definition of quarry.

# %% [markdown]
# Only one third of the test set is labellised as quarry, it is probably for the test purpose. Therefore, we won't use the site_type col and perform a classification as if all the images were potentially a quarry.

# %% [markdown]
# # Open images

# %%
my_image = cv2.imread(X_train.image_path[0])
plt.imshow(my_image)

# %%
f"The pixels values varies from {my_image.min()} to {my_image.max()} the image has the following shape {my_image.shape}"
# Out:
# 'The pixels values varies from 0 to 254 the image has the following shape (1024, 1024, 3)'

# %% [markdown]
# ## Check images size

# %%
def check_image_sizes(image_paths):
    sizes = set()
    for path in image_paths:
        with Image.open(path) as img:
            sizes.add(img.size)
    return sizes

# Example usage with X_train and X_test image paths
train_image_sizes = check_image_sizes(X_train['image_path'])
test_image_sizes = check_image_sizes(X_test['image_path'])

# Display the sizes
print(f"Unique sizes in training images: {train_image_sizes}")
print(f"Unique sizes in test images: {test_image_sizes}")

# Check if all images are the same size
if len(train_image_sizes) == 1:
    print("All training images are of the same size.")
else:
    print("Training images have different sizes.")

if len(test_image_sizes) == 1:
    print("All test images are of the same size.")
else:
    print("Test images have different sizes.")
# Out:
# Unique sizes in training images: {(1024, 1024)}
# Unique sizes in test images: {(1024, 1024)}
# All training images are of the same size.
# All test images are of the same size.

# %% [markdown]
# # CLass imbalance

# %%
Y_train.sum()/len(Y_train)
# Out:
# output    0.487969
# dtype: float64
